# %%
from RGBHallucinator import Hallucinator
import os
import time
import signal

# %%
pid_list =[]
pid = os.fork()
if pid == 0 :
    H_s2= Hallucinator('config.ini',2,0)
    H_s2.train()
else :
    pid_list.append(os.getpid())
    pid=os.fork()
    if pid == 0 :
        H_s4= Hallucinator('config.ini',4,1)
        H_s4.train()
    else :
        pid_list.append(os.getpid())
        pid = os.fork()
        if pid == 0 :
            H_s8= Hallucinator('config.ini',8,2)
            H_s8.train()
        else :
            pid_list.append(os.getpid())
            H_s16=Hallucinator('config.ini',16,2)
            H_s16.train()
            for p in pid_list:        
                os.waitpid(p,0)
            


print ("Training procedures of all scales completed")
# Out:
# Initializing Hallucinator class
# Initializing Hallucinator class
# Initializing Hallucinator class
# Reading configuration File
# Reading configuration File
# Using the latest trained model in check point file
# Reading configuration File
# Using the latest trained model in check point file
# Using the latest trained model in check point file
# Initializing Data Reader
# Initializing Data Reader
# Initializing Data Reader
# Train files 108256
# Test  files 27064
# Initialization Complete
# Train files 108256
# Train files 108256
# Test  files 27064
# Test  files 27064
# Initialization Complete
# Initialization Complete
# Initializing Hallucinator class
# Reading configuration File
# Using the latest trained model in check point file
# Initializing Data Reader
# Train files 108256
# Test  files 27064
# Initialization Complete
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-a614b30d203d> in <module>()
#       8 if pid == 0 :
#       9     H_s2= Hallucinator('config.ini',2,0)
# ---> 10     H_s2.train()
#      11 else :
#      12     pid_list.append(os.getpid())
#
# /home/exx/Kausic/Hallucination/src/RGBHallucinator.pyc in train(self)
#     138         config=tf.ConfigProto()
#     139         config.gpu_options.allow_growth=True
# --> 140         self.sess = tf.Session(config=config)
#     141         train_summary_writer=tf.summary.FileWriter(os.path.join(self.summary_writer_dir,'train'),self.sess.graph)
#     142         test_summary_writer=tf.summary.FileWriter(os.path.join(self.summary_writer_dir,'test'),self.sess.graph)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in __init__(self, target, graph, config)
#    1492
#    1493     """
# -> 1494     super(Session, self).__init__(target, graph, config=config)
#    1495     # NOTE(mrry): Create these on first `__enter__` to avoid a reference cycle.
#    1496     self._default_graph_context_manager = None
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in __init__(self, target, graph, config)
#     624     try:
#     625       # pylint: disable=protected-access
# --> 626       self._session = tf_session.TF_NewSession(self._graph._c_graph, opts)
#     627       # pylint: enable=protected-access
#     628     finally:
#
# KeyboardInterrupt:
